# %%
import pandas as pd 
import numpy as np 

from sklearn.preprocessing import  OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

import plotly.express as px
import plotly.io as pio
pio.renderers.default = "vscode"

# %%
data = pd.read_csv("uber-raw-data-may14.csv")
data.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  5/1/2014 0:02:00  40.7521 -73.9914  B02512
# 1  5/1/2014 0:06:00  40.6965 -73.9715  B02512
# 2  5/1/2014 0:15:00  40.7464 -73.9838  B02512
# 3  5/1/2014 0:17:00  40.7463 -74.0011  B02512
# 4  5/1/2014 0:17:00  40.7594 -73.9734  B02512

# %%
data_sample = data.sample(20000)

# %%
# Basic stats
print("Number of rows : {}".format(data_sample.shape[0]))
print("Number of columns : {}".format(data_sample.shape[1]))
print()


print("Percentage of missing values: ")
display(100*data_sample.isnull().sum()/data_sample.shape[0])
# Out:
# Number of rows : 20000
# Number of columns : 4
#
# Percentage of missing values:
# Date/Time    0.0
# Lat          0.0
# Lon          0.0
# Base         0.0
# dtype: float64

# %%
data_sample['Date/Time']= pd.to_datetime(data_sample['Date/Time'])
data_sample.dtypes
# Out:
# Date/Time    datetime64[ns]
# Lat                 float64
# Lon                 float64
# Base                 object
# dtype: object

# %%
# split Date column into 2 parts (day and day of week) and drop Date column
data_sample['DayOfWeek'] =data_sample['Date/Time'].dt.dayofweek
data_sample['Day'] =data_sample['Date/Time'].dt.day
data_sample['Hour'] =data_sample['Date/Time'].dt.hour

# %%
data_sample.head()
# Out:
#                  Date/Time      Lat      Lon    Base  DayOfWeek  Day  Hour
# 482525 2014-05-09 07:20:00  40.7641 -73.9787  B02682          4    9     7
# 471355 2014-05-07 23:21:00  40.7254 -73.9931  B02682          2    7    23
# 401291 2014-05-28 14:33:00  40.7231 -74.0025  B02617          2   28    14
# 109478 2014-05-09 17:31:00  40.7325 -73.9936  B02598          4    9    17
# 53098  2014-05-02 21:07:00  40.7421 -73.9829  B02598          4    2    21

# %%
print("Number of rows : {}".format(data_sample.shape[0]))
print("Number of columns : {}".format(data_sample.shape[1]))
print()
# Out:
# Number of rows : 20000
# Number of columns : 7

# %%
## map without clustering
fig = px.scatter_mapbox(
        data_sample, 
        lat="Lat", 
        lon="Lon",
        color="DayOfWeek",
        mapbox_style="carto-positron"
)

fig.show()

# %%
data_sample.drop('Date/Time', axis = 1, inplace = True)

# %%
data_sample.head()
# Out:
#             Lat      Lon    Base  DayOfWeek  Day  Hour
# 482525  40.7641 -73.9787  B02682          4    9     7
# 471355  40.7254 -73.9931  B02682          2    7    23
# 401291  40.7231 -74.0025  B02617          2   28    14
# 109478  40.7325 -73.9936  B02598          4    9    17
# 53098   40.7421 -73.9829  B02598          4    2    21

# %%
## map without clustering
fig = px.scatter_mapbox(
        data_sample, 
        lat="Lat", 
        lon="Lon",
        color="Day",
        mapbox_style="carto-positron"
)

fig.show()
